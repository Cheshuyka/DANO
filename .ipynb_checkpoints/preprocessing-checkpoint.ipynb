# %% [markdown]
# Пока что делаем все в одном документе, уже потом все поделим по папкам и т.д.

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df = pd.read_excel("T_cashback_dataset.xlsx")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-9-63f4ee4f4cc5> in <cell line: 1>()
# ----> 1 df = pd.read_excel("T_cashback_dataset.xlsx")
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/excel/_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, thousands, decimal, comment, skipfooter, convert_float, mangle_dupe_cols, storage_options)
#     480     if not isinstance(io, ExcelFile):
#     481         should_close = True
# --> 482         io = ExcelFile(io, storage_options=storage_options, engine=engine)
#     483     elif engine and engine != io.engine:
#     484         raise ValueError(
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/excel/_base.py in __init__(self, path_or_buffer, engine, storage_options)
#    1650                 ext = "xls"
#    1651             else:
# -> 1652                 ext = inspect_excel_format(
#    1653                     content_or_path=path_or_buffer, storage_options=storage_options
#    1654                 )
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/excel/_base.py in inspect_excel_format(content_or_path, storage_options)
#    1523         content_or_path = BytesIO(content_or_path)
#    1524
# -> 1525     with get_handle(
#    1526         content_or_path, "rb", storage_options=storage_options, is_text=False
#    1527     ) as handle:
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     863         else:
#     864             # Binary mode
# --> 865             handle = open(handle, ioargs.mode)
#     866         handles.append(handle)
#     867
#
# FileNotFoundError: [Errno 2] No such file or directory: 'T_cashback_dataset.xlsx'

# %%
pd.set_option('display.max_columns', None) # чтобы видеть все столбцы при выводе таблицы

# %% [markdown]
# Есть вероятность, что нам не понадобятся колонки `total` и `total_cashback`, но пока я не уверен

# %%
df['total'] = df.loc[:, ['оборот_аптеки', 'оборот_рестораны',
       'оборот_одежда_и_обувь', 'оборот_автоуслуги', 'оборот_супермаркеты',
       'оборот_такси', 'оборот_красота', 'оборот_развлечения',
       'оборот_жд_билеты', 'оборот_образование', 'оборот_дом_и_ремонт',
       'оборот_спорттовары', 'оборот_животные', 'оборот_цветы',
       'оборот_фастфуд', 'оборот_каршеринг', 'оборот_аренда_авто']].sum(axis=1)
df['total_cashback'] = df.loc[:, ['кэшбэк_аптеки', 'кэшбэк_рестораны',
       'кэшбэк_одежда_и_обувь', 'кэшбэк_автоуслуги', 'кэшбэк_супермаркеты',
       'кэшбэк_такси', 'кэшбэк_красота', 'кэшбэк_развлечения',
       'кэшбэк_жд_билеты', 'кэшбэк_образование', 'кэшбэк_дом_и_ремонт',
       'кэшбэк_спорттовары', 'кэшбэк_животные', 'кэшбэк_цветы',
       'кэшбэк_фастфуд', 'кэшбэк_каршеринг', 'кэшбэк_аренда_авто']].sum(axis=1)

# %%
df = df.loc[:, ['ключ_клиента', 'регион_проживания', 'город_проживания', 'возраст',
       'пол', 'месяц_покупок', 'total', 'total_cashback', 'оборот_аптеки', 'оборот_рестораны',
       'оборот_одежда_и_обувь', 'оборот_автоуслуги', 'оборот_супермаркеты',
       'оборот_такси', 'оборот_красота', 'оборот_развлечения',
       'оборот_жд_билеты', 'оборот_образование', 'оборот_дом_и_ремонт',
       'оборот_спорттовары', 'оборот_животные', 'оборот_цветы',
       'оборот_фастфуд', 'оборот_каршеринг', 'оборот_аренда_авто',
       'активация_кэшбэка_аптеки', 'активация_кэшбэка_рестораны',
       'активация_кэшбэка_одежда_и_обувь', 'активация_кэшбэка_автоуслуги',
       'активация_кэшбэка_супермаркеты', 'активация_кэшбэка_такси',
       'активация_кэшбэка_красота', 'активация_кэшбэка_развлечения',
       'активация_кэшбэка_жд_билеты', 'активация_кэшбэка_образование',
       'активация_кэшбэка_дом_и_ремонт', 'активация_кэшбэка_спорттовары',
       'активация_кэшбэка_животные', 'активация_кэшбэка_цветы',
       'активация_кэшбэка_фастфуд', 'активация_кэшбэка_каршеринг',
       'активация_кэшбэка_аренда_авто', 'кэшбэк_аптеки', 'кэшбэк_рестораны',
       'кэшбэк_одежда_и_обувь', 'кэшбэк_автоуслуги', 'кэшбэк_супермаркеты',
       'кэшбэк_такси', 'кэшбэк_красота', 'кэшбэк_развлечения',
       'кэшбэк_жд_билеты', 'кэшбэк_образование', 'кэшбэк_дом_и_ремонт',
       'кэшбэк_спорттовары', 'кэшбэк_животные', 'кэшбэк_цветы',
       'кэшбэк_фастфуд', 'кэшбэк_каршеринг', 'кэшбэк_аренда_авто']]

# %%
new_names = ['client_id', 'region', 'city', 'age', 'sex', 'month', 'total',
       'total_cashback', 'pharmacy', 'restaurants', 'clothes', 'car_service',
       'supermarkets', 'taxi', 'beauty', 'entertainment', 'railway',
       'education', 'house', 'sports_goods', 'pets', 'flowers', 'fastfood',
       'carsharing', 'rent_car', 'act_pharmacy', 'act_restaurants',
       'act_clothes', 'act_car_service', 'act_supermarkets', 'act_taxi',
       'act_beauty', 'act_entertainment', 'act_railway', 'act_education',
       'act_house', 'act_sports_goods', 'act_pets', 'act_flowers',
       'act_fastfood', 'act_carsharing', 'act_rent_car', 'back_pharmacy',
       'back_restaurants', 'back_clothes', 'back_car_service',
       'back_supermarkets', 'back_taxi', 'back_beauty', 'back_entertainment',
       'back_railway', 'back_education', 'back_house', 'back_sports_goods',
       'back_pets', 'back_flowers', 'back_fastfood', 'back_carsharing',
       'back_rent_car']
df = df.rename(columns=dict(zip(df.columns, new_names)))

# %% [markdown]
# *log*: поменял имена кэшбеков по формуле:
# `cash_{название} -> back_{название}`

# %%
df.to_csv("cashback_copy.csv")

# %%
new = df.loc[:, 'act_pharmacy':'act_rent_car'].sum(axis=1)
new.loc[new == 4].size
# Out:
# 724

# %%
(df.loc[:, ['act_pharmacy', 'act_restaurants',
       'act_clothes', 'act_car_service', 'act_supermarkets', 'act_taxi',
       'act_beauty', 'act_entertainment', 'act_railway', 'act_education',
       'act_house', 'act_sports_goods', 'act_pets', 'act_flowers',
       'act_fastfood', 'act_carsharing', 'act_rent_car']].count(axis=1) > 4).sum()
# Out:
# 14203

# %%
(df.loc[:, ['act_pharmacy', 'act_restaurants',
       'act_clothes', 'act_car_service', 'act_supermarkets', 'act_taxi',
       'act_beauty', 'act_entertainment', 'act_railway', 'act_education',
       'act_house', 'act_sports_goods', 'act_pets', 'act_flowers',
       'act_fastfood', 'act_carsharing', 'act_rent_car']].sum(axis=1) > 4).sum()
# Out:
# 0

# %%
df
# Out:
#         client_id  region    city  age  sex      month      total  \
# 0            1889  Москва  Москва   50    M 2023-04-01   769455.0
# 1            1889  Москва  Москва   50    M 2023-05-01   817209.0
# 2            1889  Москва  Москва   50    M 2023-06-01  1059606.0
# 3            1889  Москва  Москва   50    M 2023-07-01  1158324.0
# 4            1889  Москва  Москва   50    M 2023-08-01  1104241.0
# ...           ...     ...     ...  ...  ...        ...        ...
# 59821  1005319581  Москва  Москва   37  NaN 2023-05-01   174758.0
# 59822  1005319581  Москва  Москва   37  NaN 2023-06-01   273375.0
# 59823  1005319581  Москва  Москва   37  NaN 2023-07-01   168676.0
# 59824  1005319581  Москва  Москва   37  NaN 2023-08-01   205576.0
# 59825  1005319581  Москва  Москва   37  NaN 2023-09-01   203287.0
#
#        total_cashback  pharmacy  restaurants  clothes  car_service  \
# 0             21186.0   18993.0      99900.0   3294.0          NaN
# 1             16161.0   37807.0      92424.0      NaN       6750.0
# 2             24009.0   20791.0     124800.0  51246.0      67490.0
# 3             28086.0  131129.0      18060.0  78120.0       2400.0
# 4             22584.0   44096.0     198480.0  19080.0     147705.0
# ...               ...       ...          ...      ...          ...
# 59821             0.0     657.0      54375.0      NaN          NaN
# 59822          5634.0       NaN     128070.0      NaN          NaN
# 59823          2907.0    5919.0      26085.0      NaN          NaN
# 59824          2427.0    1705.0     111690.0      NaN          NaN
# 59825          3282.0    2832.0      89370.0      NaN          NaN
#
#        supermarkets      taxi    beauty  entertainment  railway  education  \
# 0          397450.0   86037.0   96570.0        27420.0      NaN        NaN
# 1          219394.0  109221.0   80520.0        76950.0      NaN        NaN
# 2          479201.0  100395.0   66165.0       113100.0      NaN        NaN
# 3          532117.0   63909.0   59280.0            NaN      NaN        NaN
# 4          286070.0   69279.0  178920.0            NaN      NaN        NaN
# ...             ...       ...       ...            ...      ...        ...
# 59821       42113.0   46719.0       NaN         6000.0      NaN        NaN
# 59822       37164.0   86751.0    1800.0         5400.0      NaN        NaN
# 59823       32419.0   31272.0       NaN        27300.0   2700.0        NaN
# 59824       16539.0   47529.0    1950.0         2778.0      NaN        NaN
# 59825       39767.0   59742.0       NaN          195.0      NaN        NaN
#
#           house  sports_goods     pets  flowers  fastfood  carsharing  \
# 0        9112.0        2100.0      NaN    660.0   27919.0         NaN
# 1       63936.0        5550.0  37147.0      NaN   87510.0         NaN
# 2       16413.0        4215.0   8122.0      NaN    7668.0         NaN
# 3      240492.0           NaN  18297.0      NaN   14520.0         NaN
# 4       58884.0       13200.0      NaN      NaN   88527.0         NaN
# ...         ...           ...      ...      ...       ...         ...
# 59821       NaN           NaN      NaN      NaN   24894.0         NaN
# 59822       NaN           NaN      NaN      NaN   14190.0         NaN
# 59823    2997.0           NaN      NaN      NaN   39984.0         NaN
# 59824       NaN           NaN      NaN      NaN   23385.0         NaN
# 59825       NaN           NaN      NaN      NaN   11381.0         NaN
#
#        rent_car  act_pharmacy  act_restaurants  act_clothes  act_car_service  \
# 0           NaN           1.0              1.0          NaN              NaN
# 1           NaN           1.0              NaN          NaN              0.0
# 2           NaN           1.0              1.0          NaN              NaN
# 3           NaN           1.0              1.0          NaN              0.0
# 4           NaN           0.0              0.0          NaN              NaN
# ...         ...           ...              ...          ...              ...
# 59821       NaN           NaN              NaN          NaN              NaN
# 59822       NaN           0.0              1.0          NaN              NaN
# 59823       NaN           0.0              NaN          NaN              NaN
# 59824       NaN           1.0              NaN          NaN              NaN
# 59825       NaN           1.0              1.0          NaN              NaN
#
#        act_supermarkets  act_taxi  act_beauty  act_entertainment  act_railway  \
# 0                   1.0       NaN         NaN                0.0          NaN
# 1                   1.0       NaN         1.0                0.0          NaN
# 2                   1.0       NaN         NaN                0.0          NaN
# 3                   1.0       NaN         NaN                NaN          NaN
# 4                   1.0       NaN         1.0                NaN          NaN
# ...                 ...       ...         ...                ...          ...
# 59821               NaN       NaN         NaN                NaN          NaN
# 59822               NaN       NaN         NaN                1.0          1.0
# 59823               NaN       1.0         0.0                1.0          0.0
# 59824               NaN       1.0         0.0                NaN          NaN
# 59825               NaN       NaN         NaN                NaN          0.0
#
#        act_education  act_house  act_sports_goods  act_pets  act_flowers  \
# 0                NaN        NaN               0.0       NaN          0.0
# 1                NaN        0.0               NaN       NaN          NaN
# 2                NaN        NaN               NaN       0.0          NaN
# 3                NaN        NaN               0.0       NaN          NaN
# 4                NaN        NaN               NaN       NaN          NaN
# ...              ...        ...               ...       ...          ...
# 59821            NaN        NaN               NaN       NaN          NaN
# 59822            NaN        NaN               0.0       NaN          NaN
# 59823            NaN        NaN               NaN       NaN          NaN
# 59824            NaN        NaN               NaN       NaN          NaN
# 59825            NaN        NaN               NaN       NaN          NaN
#
#        act_fastfood  act_carsharing  act_rent_car  cash_pharmacy  \
# 0               NaN             NaN           NaN          864.0
# 1               NaN             NaN           NaN         1884.0
# 2               NaN             NaN           NaN           21.0
# 3               NaN             NaN           NaN         6033.0
# 4               NaN             NaN           NaN            NaN
# ...             ...             ...           ...            ...
# 59821           NaN             NaN           NaN            NaN
# 59822           NaN             NaN           NaN            NaN
# 59823           NaN             NaN           NaN            NaN
# 59824           NaN             NaN           NaN           84.0
# 59825           NaN             NaN           NaN          138.0
#
#        cash_restaurants  cash_clothes  cash_car_service  cash_supermarkets  \
# 0                 486.0           NaN               NaN            19836.0
# 1                   NaN           NaN               NaN            10614.0
# 2                2025.0           NaN               NaN            21963.0
# 3                   NaN           NaN               NaN            22053.0
# 4                   NaN           NaN               NaN            13491.0
# ...                 ...           ...               ...                ...
# 59821               NaN           NaN               NaN                NaN
# 59822            5364.0           NaN               NaN                NaN
# 59823               NaN           NaN               NaN                NaN
# 59824               NaN           NaN               NaN                NaN
# 59825            3144.0           NaN               NaN                NaN
#
#        cash_taxi  cash_beauty  cash_entertainment  cash_railway  \
# 0            NaN          NaN                 NaN           NaN
# 1            NaN       3663.0                 NaN           NaN
# 2            NaN          NaN                 NaN           NaN
# 3            NaN          NaN                 NaN           NaN
# 4            NaN       9093.0                 NaN           NaN
# ...          ...          ...                 ...           ...
# 59821        NaN          NaN                 NaN           NaN
# 59822        NaN          NaN               270.0           NaN
# 59823     1542.0          NaN              1365.0           NaN
# 59824     2343.0          NaN                 NaN           NaN
# 59825        NaN          NaN                 NaN           NaN
#
#        cash_education  cash_house  cash_sports_goods  cash_pets  cash_flowers  \
# 0                 NaN         NaN                NaN        NaN           NaN
# 1                 NaN         NaN                NaN        NaN           NaN
# 2                 NaN         NaN                NaN        NaN           NaN
# 3                 NaN         NaN                NaN        NaN           NaN
# 4                 NaN         NaN                NaN        NaN           NaN
# ...               ...         ...                ...        ...           ...
# 59821             NaN         NaN                NaN        NaN           NaN
# 59822             NaN         NaN                NaN        NaN           NaN
# 59823             NaN         NaN                NaN        NaN           NaN
# 59824             NaN         NaN                NaN        NaN           NaN
# 59825             NaN         NaN                NaN        NaN           NaN
#
#        cash_fastfood  cash_carsharing  cash_rent_car
# 0                NaN              NaN            NaN
# 1                NaN              NaN            NaN
# 2                NaN              NaN            NaN
# 3                NaN              NaN            NaN
# 4                NaN              NaN            NaN
# ...              ...              ...            ...
# 59821            NaN              NaN            NaN
# 59822            NaN              NaN            NaN
# 59823            NaN              NaN            NaN
# 59824            NaN              NaN            NaN
# 59825            NaN              NaN            NaN
#
# [59826 rows x 59 columns]

# %% [markdown]
# Узнать то, насколько менялся выбор кэшбэка от месяца к месяцу

# %%
ser = pd.Series(dtype=int)
last_ind = 0
for i in range(0, 59821, 6):
  person = df.iloc[i:i + 6].loc[:, 'act_pharmacy':'act_rent_car']
  for j in range(1, 6):
    res = 0
    first = person.iloc[j - 1].loc[person.iloc[j - 1] == 1].index
    second = person.iloc[j].loc[person.iloc[j] == 1].index
    for ind in second:
      if ind not in first:
        res += 1
    ser.at[last_ind] = res
    last_ind += 1
ser
# Out:
# 0        1
# 1        1
# 2        0
# 3        1
# 4        1
#         ..
# 49850    0
# 49851    3
# 49852    1
# 49853    1
# 49854    1
# Length: 49855, dtype: int64

# %%
ser.mean()
# Out:
# 1.335492929495537

# %%
ser = pd.Series(dtype=int)
last_ind = 0
for i in range(0, 59821, 6):
  person = df.iloc[i:i + 6].loc[:, 'act_pharmacy':'act_rent_car']
  a = set()
  for j in range(6):
    second = person.iloc[j].loc[person.iloc[j] == 1].index
    for ind in second:
      a.add(ind)
  ser.at[last_ind] = len(a)
  last_ind += 1
ser
# Out:
# 0       5
# 1       8
# 2       8
# 3       7
# 4       6
#        ..
# 9966    4
# 9967    5
# 9968    6
# 9969    6
# 9970    5
# Length: 9971, dtype: int64

# %%
ser.mean()
# Out:
# 6.138902818172701

# %%
acts = df.loc[:, 'act_pharmacy':'act_rent_car']
df1 = pd.DataFrame(columns=acts.columns)
for i in range(0, 59821, 6):
    act = acts.iloc[i:i + 6].sum(axis=0)
    df1.loc[-1] = act
    df1.index += 1
df1 = df1.sort_index()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-27-177d82a09c98> in <cell line: 3>()
#       3 for i in range(0, 59821, 6):
#       4   act = acts.iloc[i:i + 6].sum(axis=0)
# ----> 5   df1.loc[-1] = act
#       6   df.index = df.index + 1
#       7 df1
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in __setitem__(self, key, value)
#     816
#     817         iloc = self if self.name == "iloc" else self.obj.iloc
# --> 818         iloc._setitem_with_indexer(indexer, value, self.name)
#     819
#     820     def _validate_key(self, key, axis: int):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in _setitem_with_indexer(self, indexer, value, name)
#    1795             self._setitem_with_indexer_split_path(indexer, value, name)
#    1796         else:
# -> 1797             self._setitem_single_block(indexer, value, name)
#    1798
#    1799     def _setitem_with_indexer_split_path(self, indexer, value, name: str):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in _setitem_single_block(self, indexer, value, name)
#    2067             # setting for extensionarrays that store dicts. Need to decide
#    2068             # if it's worth supporting that.
# -> 2069             value = self._align_series(indexer, Series(value))
#    2070
#    2071         elif isinstance(value, ABCDataFrame) and name != "iloc":
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in _align_series(self, indexer, ser, multiindex_indexer)
#    2300
#    2301             if ser.index.equals(ax):
# -> 2302                 return ser._values.copy()
#    2303
#    2304             return ser.reindex(ax)._values
#
# KeyboardInterrupt:

# %%
for i in df1.columns:
    print(f'{i}: {len(df1[(2 <= df1[i]) & (df1[i] <= 4)])}')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-8df1b353cdf4> in <cell line: 1>()
# ----> 1 for i in df1.columns:
#       2     print(f'{i}: {len(df1[(2 <= df1[i]) & (df1[i] <= 4)])}')
#
# NameError: name 'df1' is not defined
